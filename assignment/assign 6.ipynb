# %%
import pandas as pd

# %%
pd.read_csv('../data/train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df = pd.read_csv('../data/train.csv')

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.shape
# Out:
# (891, 12)

# %%
total_passenger = len(train_df)

# %%
total_passenger
# Out:
# 891

# %% [markdown]
# # Q1. How many passangers survived this accident ?

# %%
survived_passenger = train_df[train_df['Survived'] == 1]

# %%
survived_passenger
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_survived_passenger = train_df.Survived.sum()

# %%
survived_passenger.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
total_survived_passenger
# Out:
# 342

# %%
print('The number of total passangers who survived the Titanic Accident is {}'.format(int(total_survived_passenger)))
# Out:
# The number of total passangers who survived the Titanic Accident is 342

# %% [markdown]
# ## What are the names of survived passangers ?

# %%
survived_passenger_name = survived_passenger[['PassengerId','Name','Sex','Age']]

# %%
survived_passenger_name
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# ..           ...                                                ...     ...
# 875          876                   Najib, Miss. Adele Kiamie "Jane"  female
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 887          888                       Graham, Miss. Margaret Edith  female
# 889          890                              Behr, Mr. Karl Howell    male
#
#       Age
# 1    38.0
# 2    26.0
# 3    35.0
# ...

# %%
survived_passenger.head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %% [markdown]
# # Q2. How many passangers died in this accident ?

# %%
died_passenger = train_df[train_df['Survived'] == 0]

# %%
died_passenger
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
total_died_passenger = len(died_passenger)

# %%
total_died_passenger
# Out:
# 549

# %%
print('The number of total passengers who died in this accident is {}'.format(total_died_passenger))
# Out:
# The number of total passengers who died in this accident is 549

# %% [markdown]
# # Q3 What is the survival rate ?

# %%
survival_rate = (total_survived_passenger / total_passenger) * 100

# %%
survival_rate
# Out:
# 38.38383838383838

# %% [markdown]
# # Q4 What is the death rate ?

# %%
death_rate = (total_died_passenger / total_passenger) * 100

# %%
death_rate
# Out:
# 61.61616161616161

# %%
print('In this accident, form the total of {} passangers, {} passangers died and {} managed to survived which accounted for {:.1f} % and {:.1f} % of total passangers, respectively'.format(int(total_passanger), int(total_died_passanger), float(total_survived_passenger), float((total_died_passenger / total_passenger) * 100), int((total_survived_passenger / total_passenger) * 100)))
# Out:
# In this accident, form the total of 891 passangers, 549 passangers died and 342.0 managed to survived which accounted for 61.6 % and 38.0 % of total passangers, respectively

# %% [markdown]
# ## How many males survived ?

# %%
male_passenger = train_df[train_df['Sex'] == 'male']

# %%
male_passenger
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
total_male_passenger = len(male_passenger)

# %%
total_male_passenger
# Out:
# 577

# %%
survived_male = survived_passenger[survived_passenger['Sex']== 'male']

# %%
survived_male
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
total_survived_male = len(survived_male)

# %%
total_survived_male
# Out:
# 109

# %%
male_survival_rate = total_survived_male / total_male_passenger

# %%
male_survival_rate
# Out:
# 0.18890814558058924

# %% [markdown]
# ## How many females survived ?

# %%
female_passenger = train_df[train_df['Sex'] == 'female']

# %%
total_female_passenger = len(female_passenger)

# %%
total_female_passenger
# Out:
# 314

# %%
survived_female = survived_passenger[survived_passenger['Sex'] == 'female']

# %%
survived_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_survived_female = len(survived_female)

# %%
total_survived_female
# Out:
# 233

# %%
female_survival_rate = total_survived_female / total_female_passenger

# %%
female_survival_rate
# Out:
# 0.7420382165605095

# %%
print('From total of {} survived passengers, {} are males while {} are females which accounted for {:.2f} % and {:.2f} % of total survived passengers, respectively.'.format((total_survived_passenger), (total_survived_male), (total_survived_female), float((toal_survived_male / total_survived_passenger) * 100), float((total_survived_female / total_survived_passenger) * 100)))
# Out:
# From total of 342 survived passengers, 109 are males while 233 are females which accounted for 31.87 % and 68.13 % of total survived passengers, respectively.

# %% [markdown]
# ## How many  males died ?

# %%
died_male = died_passenger[died_passenger['Sex']== 'male']

# %%
died_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
total_died_male = len(died_male)

# %%
total_died_male
# Out:
# 468

# %% [markdown]
# ## How many females died ?

# %%
died_female = died_passenger[died_passenger['Sex'] == 'female']

# %%
died_female
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_died_female = len(died_female)

# %%
total_died_female
# Out:
# 81

# %%
print('From the total of {} died passengers, {} are males while {} are females which accounted for {:.2f} % and {:.2f} % of total died passengers, respectively.'.format((total_died_passenger), (total_died_male), (total_died_female), float((total_died_male / total_died_passenger) * 100), float((total_died_female / total_died_passenger) * 100)))
# Out:
# From the total of 549 died passengers, 468 are males while 81 are females which accounted for 85.25 % and 14.75 % of total died passengers, respectively.

# %% [markdown]
# ## What is passanger survival rate accordimg to their sex ?

# %%
print('Males have {:.2F} survival rate, while females have {:.2F} survival rate.'.format(float(male_survival_rate),float(female_survival_rate)))
# Out:
# Males have 0.19 survival rate, while females have 0.74 survival rate.

# %% [markdown]
# ## What is the average age of the survived passengers ?

# %%
avg_age_survived = survived_passenger['Age'].mean()

# %% [markdown]
# ## What is the average age of died passengers ?

# %%
int(avg_age_survived)
# Out:
# 28

# %%
avg_age_died = died_passenger['Age'].mean()

# %%
int(avg_age_died)
# Out:
# 30

# %%
kids_passenger = train_df[train_df['Age'] < 10]

# %%
kids_passenger
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
train_df.sort_values('Age', ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
train_df.sort_values('Age', ascending=True).tail(100)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 388          389         0       3                      Sadlier, Mr. Matthew
# 409          410         0       3                        Lefebre, Miss. Ida
# 410          411         0       3                        Sdycoff, Mr. Todor
# 411          412         0       3                           Hart, Mr. Henry
# 413          414         0       2            Cunningham, Mr. Alfred Fleming
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# ## What are the survival rates according to the passanger class ?

# %% [markdown]
# ### Class 1

# %%
class1 = train_df[train_df['Pclass'] == 1]

# %%
total_class1 = len(class1)

# %%
total_class1
# Out:
# 216

# %%
class1_survived = survived_passenger[survived_passenger['Pclass'] == 1]

# %%
class1_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_class1_survived = len(class1_survived)

# %%
class1_died = died_passenger[died_passenger['Pclass'] == 1]

# %%
total_class1_died = len(class1_died)

# %% [markdown]
# ### Class 2

# %%
class2 = train_df[train_df['Pclass'] == 2]

# %%
total_class2 = len(class2)

# %%
total_class2
# Out:
# 184

# %%
class2_survived = survived_passenger [survived_passenger['Pclass'] == 2]

# %%
class2_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 21            22         1       2
# 43            44         1       2
# ..           ...       ...     ...
# 831          832         1       2
# 865          866         1       2
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
#
#                                              Name     Sex    Age  SibSp  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.00      0
# 17                   Williams, Mr. Charles Eugene    male    NaN      0
# 21                          Beesley, Mr. Lawrence    male  34.00      0
# 43       Laroche, Miss. Simonne Marie Anne Andree  female   3.00      1
# ..                                            ...     ...    ...    ...
# ...

# %%
total_class2_survived = len(class2_survived)

# %%
class2_died = died_passenger[died_passenger['Pclass'] == 2]

# %%
total_class2_died = len(class2_died)

# %% [markdown]
# ### Class 3

# %%
class3 = train_df[train_df['Pclass'] == 3]

# %%
class3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
total_class3 = len(class3)

# %%
class3_survived = survived_passenger[survived_passenger['Pclass'] == 3]

# %%
class3_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_class3_survived = len(class3_survived)

# %%
class3_died = died_passenger[died_passenger['Pclass'] == 3]

# %%
total_class3_died = len(class3_died)

# %%
print('According to the Passanger Class,\n there are {} 1st class passengers who died and {} survived,\n there are {} 2nd class passengers who died and {} survived,\n there are {} 3rd class passengers who died and {} survived'.format((total_class1_died), (total_class1_survived), (total_class2_died), (total_class2_survived), (total_class3_died), (total_class3_survived)))
# Out:
# According to the Passanger Class,
#  there are 80 1st class passengers who died and 136 survived,
#  there are 97 2nd class passengers who died and 87 survived,
#  there are 372 3rd class passengers who died and 119 survived

# %%
print('The rate of survival according to the Passanger Class :\n 1st class = {:.2f},\n 2nd class = {:.2f},\n 3rd class = {:.2f}'.format((total_class1_survived / total_class1), (total_class2_survived / total_class2), (total_class3_survived / total_class3)))
# Out:
# The rate of survival according to the Passanger Class :
#  1st class = 0.63,
#  2nd class = 0.47,
#  3rd class = 0.24

# %%
age_group = train_df.groupby('Age')['Survived'].sum()

# %%
age_group
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    0
# 70.50    0
# 71.00    0
# 74.00    0
# 80.00    1
# Name: Survived, Length: 88, dtype: int64
